# %% [markdown]
# # How to Train Detectron2 for Custom Instance Segmentation
#
# This tutorial is based on the [Detectron2 repository](https://github.com/facebookresearch/detectron2) by Facebook. This notebook shows training on **your own custom instance segmentation objects**.
#
# ### Accompanying Blog Post
#
# We recommend that you follow along in this notebook while reading the blog post on [how to train Detectron2 for custom instance segmentation](https://blog.roboflow.ai/custom-detectron2-instance-segmentation/), concurrently.
#
# ### Steps Covered in this Tutorial
#
# In this tutorial, we will walk through the steps required to train Detectron2 on your custom instance segmentation objects. We use a public [American Sign Language instance segmentation dataset](https://public.roboflow.ai/object-detection/bccd), which is open source and free to use. You can also use this notebook on your own data.
#
# To train our segmenter we take the following steps:
#
# * Install Detectron2 dependencies
# * Download custom instance segmentation data from Roboflow
# * Visualize Detectron2 training data
# * Write our Detectron2 Training configuration
# * Run Detectron2 training
# * Evaluate Dectron2 performance
# * Run Detectron2 inference on test images
# * Export saved Detectron2 weights for future inference
#
# ### **About**
#
# [Roboflow](https://roboflow.com) enables teams to deploy custom computer vision models quickly and accurately. Convert data from to annotation format, assess dataset health, preprocess, augment, and more. It's free for your first 1000 source images.
#
# **Looking for a vision model available via API without hassle? Try Roboflow Train.**
#
# ![Roboflow Wordmark](https://i.imgur.com/dcLNMhV.png)

# %% [markdown]
# # Install Roboflow and Detectron2 Pip Packages, Import Deps

# %%
# !python -m pip install roboflow
# !python -m pip install 'git+https://github.com/facebookresearch/detectron2.git'
# Out:
# Collecting roboflow
#   Downloading roboflow-1.1.2-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.4/57.4 kB 1.2 MB/s eta 0:00:00
# Collecting certifi==2022.12.7 (from roboflow)
#   Downloading certifi-2022.12.7-py3-none-any.whl (155 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 6.4 MB/s eta 0:00:00
# Requirement already satisfied: chardet==4.0.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.0.0)
# Collecting cycler==0.10.0 (from roboflow)
#   Downloading cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Collecting idna==2.10 (from roboflow)
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 5.4 MB/s eta 0:00:00
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.4.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from roboflow) (3.7.1)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.22.4)
# Requirement already satisfied: opencv-python>=4.1.2 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.7.0.72)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from roboflow) (8.4.0)
# Collecting pyparsing==2.4.7 (from roboflow)
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 6.3 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.8.2)
# Collecting python-dotenv (from roboflow)
#   Downloading python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.27.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.16.0)
# Collecting supervision (from roboflow)
#   Downloading supervision-0.12.0-py3-none-any.whl (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 kB 4.2 MB/s eta 0:00:00
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.26.16)
# Collecting wget (from roboflow)
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.65.0)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (6.0.1)
# Collecting requests-toolbelt (from roboflow)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 4.3 MB/s eta 0:00:00
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (1.1.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (4.41.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (23.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->roboflow) (2.0.12)
# Requirement already satisfied: opencv-python-headless<5.0.0.0,>=4.8.0.74 in /usr/local/lib/python3.10/dist-packages (from supervision->roboflow) (4.8.0.74)
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9657 sha256=f7089e6968670b74932fa5d9dfe76e683f8586f12417cdaea9405fb5ce9eba99
#   Stored in directory: /root/.cache/pip/wheels/8b/f1/7f/5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
# Successfully built wget
# Installing collected packages: wget, python-dotenv, pyparsing, idna, cycler, certifi, supervision, requests-toolbelt, roboflow
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.0
#     Uninstalling pyparsing-3.1.0:
#       Successfully uninstalled pyparsing-3.1.0
#   Attempting uninstall: idna
#     Found existing installation: idna 3.4
#     Uninstalling idna-3.4:
#       Successfully uninstalled idna-3.4
#   Attempting uninstall: cycler
#     Found existing installation: cycler 0.11.0
#     Uninstalling cycler-0.11.0:
#       Successfully uninstalled cycler-0.11.0
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2023.5.7
#     Uninstalling certifi-2023.5.7:
#       Successfully uninstalled certifi-2023.5.7
# Successfully installed certifi-2022.12.7 cycler-0.10.0 idna-2.10 pyparsing-2.4.7 python-dotenv-1.0.0 requests-toolbelt-1.0.0 roboflow-1.1.2 supervision-0.12.0 wget-3.2
# Collecting git+https://github.com/facebookresearch/detectron2.git
#   Cloning https://github.com/facebookresearch/detectron2.git to /tmp/pip-req-build-hbbp6meg
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/detectron2.git /tmp/pip-req-build-hbbp6meg
#   Resolved https://github.com/facebookresearch/detectron2.git to commit a2e43eab54d28ffbd59f5e9b4e3193b82faeb70f
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: Pillow>=7.1 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (8.4.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (3.7.1)
# Requirement already satisfied: pycocotools>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (2.0.6)
# Requirement already satisfied: termcolor>=1.1 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (2.3.0)
# Collecting yacs>=0.1.8 (from detectron2==0.6)
#   Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (0.9.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (2.2.1)
# Requirement already satisfied: tqdm>4.29.0 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (4.65.0)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (2.12.3)
# Collecting fvcore<0.1.6,>=0.1.5 (from detectron2==0.6)
#   Downloading fvcore-0.1.5.post20221221.tar.gz (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 2.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting iopath<0.1.10,>=0.1.7 (from detectron2==0.6)
#   Downloading iopath-0.1.9-py3-none-any.whl (27 kB)
# Collecting omegaconf>=2.1 (from detectron2==0.6)
#   Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 4.6 MB/s eta 0:00:00
# Collecting hydra-core>=1.1 (from detectron2==0.6)
#   Downloading hydra_core-1.3.2-py3-none-any.whl (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 5.5 MB/s eta 0:00:00
# Collecting black (from detectron2==0.6)
#   Downloading black-23.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 9.3 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (23.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from fvcore<0.1.6,>=0.1.5->detectron2==0.6) (1.22.4)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from fvcore<0.1.6,>=0.1.5->detectron2==0.6) (6.0.1)
# Collecting antlr4-python3-runtime==4.9.* (from hydra-core>=1.1->detectron2==0.6)
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 12.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting portalocker (from iopath<0.1.10,>=0.1.7->detectron2==0.6)
#   Downloading portalocker-2.7.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (0.10.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (4.41.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (2.8.2)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from black->detectron2==0.6) (8.1.6)
# Collecting mypy-extensions>=0.4.3 (from black->detectron2==0.6)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Collecting pathspec>=0.9.0 (from black->detectron2==0.6)
#   Downloading pathspec-0.11.1-py3-none-any.whl (29 kB)
# Requirement already satisfied: platformdirs>=2 in /usr/local/lib/python3.10/dist-packages (from black->detectron2==0.6) (3.9.1)
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from black->detectron2==0.6) (2.0.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (1.56.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (3.4.3)
# Requirement already satisfied: protobuf>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (2.27.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (67.7.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (2.3.6)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (0.40.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from cycler>=0.10->matplotlib->detectron2==0.6) (1.16.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard->detectron2==0.6) (1.3.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (2.10)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard->detectron2==0.6) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard->detectron2==0.6) (3.2.2)
# Building wheels for collected packages: detectron2, fvcore, antlr4-python3-runtime
#   Building wheel for detectron2 (setup.py) ... done
#   Created wheel for detectron2: filename=detectron2-0.6-cp310-cp310-linux_x86_64.whl size=6111761 sha256=f11d67b428cf6f357d6ec161a8bb3a1626a2174fed914318433023dc345d8797
#   Stored in directory: /tmp/pip-ephem-wheel-cache-41gr48ni/wheels/47/e5/15/94c80df2ba85500c5d76599cc307c0a7079d0e221bb6fc4375
#   Building wheel for fvcore (setup.py) ... done
#   Created wheel for fvcore: filename=fvcore-0.1.5.post20221221-py3-none-any.whl size=61405 sha256=d468f99daeda74e274e47c5fc7c828e05ab05d0c195fd990320e8fa37830111b
#   Stored in directory: /root/.cache/pip/wheels/01/c0/af/77c1cf53a1be9e42a52b48e5af2169d40ec2e89f7362489dd0
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144554 sha256=bc8b2511ba18a0e43f4e7d75dc878ccc5027908a42d46e9acaec5138d337221b
#   Stored in directory: /root/.cache/pip/wheels/12/93/dd/1f6a127edc45659556564c5730f6d4e300888f4bca2d4c5a88
# Successfully built detectron2 fvcore antlr4-python3-runtime
# Installing collected packages: antlr4-python3-runtime, yacs, portalocker, pathspec, omegaconf, mypy-extensions, iopath, hydra-core, black, fvcore, detectron2
# Successfully installed antlr4-python3-runtime-4.9.3 black-23.7.0 detectron2-0.6 fvcore-0.1.5.post20221221 hydra-core-1.3.2 iopath-0.1.9 mypy-extensions-1.0.0 omegaconf-2.3.0 pathspec-0.11.1 portalocker-2.7.0 yacs-0.1.8

# %%
import logging
import torch
from collections import OrderedDict
import detectron2
from detectron2.utils.logger import setup_logger
setup_logger()

# import some common libraries
import numpy as np
import os, json, cv2, random

# import some common detectron2 utilities
from detectron2 import model_zoo
from detectron2.engine import DefaultPredictor
from detectron2.config import get_cfg
from detectron2.utils.visualizer import Visualizer
from detectron2.data import MetadataCatalog, DatasetCatalog
from detectron2.data.datasets import register_coco_instances
from detectron2.engine import DefaultTrainer
from detectron2.utils.visualizer import ColorMode
from detectron2.solver import build_lr_scheduler, build_optimizer
from detectron2.checkpoint import DetectionCheckpointer, PeriodicCheckpointer
from detectron2.utils.events import EventStorage
from detectron2.modeling import build_model
import detectron2.utils.comm as comm
from detectron2.engine import default_argument_parser, default_setup, default_writers, launch
from detectron2.data import (
    MetadataCatalog,
    build_detection_test_loader,
    build_detection_train_loader,
)
from detectron2.evaluation import (
    CityscapesInstanceEvaluator,
    CityscapesSemSegEvaluator,
    COCOEvaluator,
    COCOPanopticEvaluator,
    DatasetEvaluators,
    LVISEvaluator,
    PascalVOCDetectionEvaluator,
    SemSegEvaluator,
    inference_on_dataset,
    print_csv_format,
)

from roboflow import Roboflow

from matplotlib import pyplot as plt
from PIL import Image

# %% [markdown]
# # Download dataset via Roboflow pip package and show a sample annotation

# %%
rf = Roboflow(api_key="WtnAj0bPePCFmKVGczUj")
project = rf.workspace("amlws").project("benchmark-mcl0x")
dataset = project.version(1).download("coco")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in BENCHmark-1 to coco: 100% [41209921 / 41209921] bytes
# Extracting Dataset Version Zip to BENCHmark-1 in coco:: 100%|██████████| 304/304 [00:00<00:00, 540.51it/s]

# %%
register_coco_instances("asl_poly_train", {}, f"./BENCHmark-1/train/_annotations.coco.json", f"./BENCHmark-1/train/")
register_coco_instances("asl_poly_valid", {}, f"./BENCHmark-1/valid/_annotations.coco.json", f"./BENCHmark-1/valid/")
register_coco_instances("asl_poly_test", {}, f"./BENCHmark-1/test/_annotations.coco.json", f"./BENCHmark-1/test/")

# %%
dataset_train = DatasetCatalog.get("asl_poly_train")
fig, ax = plt.subplots()
dataset_dict = random.choice(dataset_train)
im = Image.open(dataset_dict['file_name'])
ax.imshow(im)
for ann in dataset_dict['annotations']:
    for poly in ann['segmentation']:
        x = poly[0::2]
        y = poly[1::2]
        ax.plot(x,y, linewidth=2, color='red')
# Out:
# WARNING [07/24 11:06:36 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [07/24 11:06:36 d2.data.datasets.coco]: Loaded 258 images in COCO format from ./BENCHmark-1/train/_annotations.coco.json

# %% [markdown]
# # Configure Detectron2 for fine tuning from COCO, Define training loop helper functions (from detectron2 repo), Run custom training loop

# %%
cfg = get_cfg()
cfg.merge_from_file(model_zoo.get_config_file("COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml"))
cfg.DATASETS.TRAIN = ("asl_poly_train",)#Train dataset registered in a previous cell
cfg.DATASETS.TEST = ("asl_poly_test",)#Test dataset registered in a previous cell
cfg.DATALOADER.NUM_WORKERS = 2
cfg.MODEL.WEIGHTS = model_zoo.get_checkpoint_url("COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml")  # Let training initialize from model zoo
cfg.SOLVER.IMS_PER_BATCH = 2
cfg.SOLVER.BASE_LR = 0.00025
cfg.SOLVER.MAX_ITER = 10000 #We found that with a patience of 500, training will early stop before 10,000 iterations
cfg.SOLVER.STEPS = []
cfg.MODEL.ROI_HEADS.BATCH_SIZE_PER_IMAGE = 512
cfg.MODEL.ROI_HEADS.NUM_CLASSES = 2 # 26 letters plus one super class
cfg.TEST.EVAL_PERIOD = 0 # Increase this number if you want to monitor validation performance during training

PATIENCE = 500 #Early stopping will occur after N iterations of no imporovement in total_loss

os.makedirs(cfg.OUTPUT_DIR, exist_ok=True)

# %%
def get_evaluator(cfg, dataset_name, output_folder=None):
    """
    Create evaluator(s) for a given dataset.
    This uses the special metadata "evaluator_type" associated with each builtin dataset.
    For your own dataset, you can simply create an evaluator manually in your
    script and do not have to worry about the hacky if-else logic here.
    """
    if output_folder is None:
        output_folder = os.path.join(cfg.OUTPUT_DIR, "inference")
    evaluator_list = []
    evaluator_type = MetadataCatalog.get(dataset_name).evaluator_type
    if evaluator_type in ["sem_seg", "coco_panoptic_seg"]:
        evaluator_list.append(
            SemSegEvaluator(
                dataset_name,
                distributed=True,
                output_dir=output_folder,
            )
        )
    if evaluator_type in ["coco", "coco_panoptic_seg"]:
        evaluator_list.append(COCOEvaluator(dataset_name, output_dir=output_folder))
    if evaluator_type == "coco_panoptic_seg":
        evaluator_list.append(COCOPanopticEvaluator(dataset_name, output_folder))
    if evaluator_type == "cityscapes_instance":
        return CityscapesInstanceEvaluator(dataset_name)
    if evaluator_type == "cityscapes_sem_seg":
        return CityscapesSemSegEvaluator(dataset_name)
    if evaluator_type == "pascal_voc":
        return PascalVOCDetectionEvaluator(dataset_name)
    if evaluator_type == "lvis":
        return LVISEvaluator(dataset_name, cfg, True, output_folder)
    if len(evaluator_list) == 0:
        raise NotImplementedError(
            "no Evaluator for the dataset {} with the type {}".format(dataset_name, evaluator_type)
        )
    if len(evaluator_list) == 1:
        return evaluator_list[0]
    return DatasetEvaluators(evaluator_list)

def do_test(cfg, model):
    results = OrderedDict()
    for dataset_name in cfg.DATASETS.TEST:
        data_loader = build_detection_test_loader(cfg, dataset_name)
        evaluator = get_evaluator(
            cfg, dataset_name, os.path.join(cfg.OUTPUT_DIR, "inference", dataset_name)
        )
        results_i = inference_on_dataset(model, data_loader, evaluator)
        results[dataset_name] = results_i
        if comm.is_main_process():
            logger.info("Evaluation results for {} in csv format:".format(dataset_name))
            print_csv_format(results_i)
    if len(results) == 1:
        results = list(results.values())[0]
    return results


logger = logging.getLogger("detectron2")
resume=False
model = build_model(cfg)
optimizer = build_optimizer(cfg, model)
scheduler = build_lr_scheduler(cfg, optimizer)

BEST_LOSS = np.inf

checkpointer = DetectionCheckpointer(
    model, cfg.OUTPUT_DIR, optimizer=optimizer, scheduler=scheduler
)
start_iter = (
    checkpointer.resume_or_load(cfg.MODEL.WEIGHTS, resume=resume).get("iteration", -1) + 1
)
prev_iter = start_iter
max_iter = cfg.SOLVER.MAX_ITER

periodic_checkpointer = PeriodicCheckpointer(
    checkpointer, cfg.SOLVER.CHECKPOINT_PERIOD, max_iter=max_iter
)

writers = default_writers(cfg.OUTPUT_DIR, max_iter) if comm.is_main_process() else []

# compared to "train_net.py", we do not support accurate timing and
# precise BN here, because they are not trivial to implement in a small training loop
data_loader = build_detection_train_loader(cfg)
logger.info("Starting training from iteration {}".format(start_iter))
patience_counter = 0
with EventStorage(start_iter) as storage:
    for data, iteration in zip(data_loader, range(start_iter, max_iter)):
        storage.iter = iteration

        loss_dict = model(data)
        losses = sum(loss_dict.values())
        assert torch.isfinite(losses).all(), loss_dict

        loss_dict_reduced = {k: v.item() for k, v in comm.reduce_dict(loss_dict).items()}
        losses_reduced = sum(loss for loss in loss_dict_reduced.values())
        if comm.is_main_process():
            storage.put_scalars(total_loss=losses_reduced, **loss_dict_reduced)

        optimizer.zero_grad()
        losses.backward()
        optimizer.step()
        storage.put_scalar("lr", optimizer.param_groups[0]["lr"], smoothing_hint=False)
        scheduler.step()

        if (
            cfg.TEST.EVAL_PERIOD > 0
            and (iteration + 1) % cfg.TEST.EVAL_PERIOD == 0
            and iteration != max_iter - 1
        ):
            do_test(cfg, model)
            # Compared to "train_net.py", the test results are not dumped to EventStorage
            comm.synchronize()

        if iteration - start_iter > 5 and (
            (iteration + 1) % 20 == 0 or iteration == max_iter - 1
        ):
            for writer in writers:
                writer.write()
        periodic_checkpointer.step(iteration)

        if iteration > prev_iter:
            prev_iter = iteration
            if losses_reduced < BEST_LOSS:
                BEST_LOSS = losses_reduced
                patience_counter = 0
            else:
                patience_counter += 1
                if patience_counter % 100 == 0:
                    print(f"Loss has not improved for {patience_counter} iterations")
                if patience_counter >= PATIENCE:
                    print(f"EARLY STOPPING")
                    break

do_test(cfg, model)
# Out:
# [07/24 11:07:18 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from https://dl.fbaipublicfiles.com/detectron2/COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x/137849600/model_final_f10217.pkl ...
# model_final_f10217.pkl: 178MB [00:00, 186MB/s]
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.box_predictor.cls_score.weight' to the model due to incompatible shapes: (81, 1024) in the checkpoint but (3, 1024) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.box_predictor.cls_score.bias' to the model due to incompatible shapes: (81,) in the checkpoint but (3,) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.box_predictor.bbox_pred.weight' to the model due to incompatible shapes: (320, 1024) in the checkpoint but (8, 1024) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.box_predictor.bbox_pred.bias' to the model due to incompatible shapes: (320,) in the checkpoint but (8,) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.mask_head.predictor.weight' to the model due to incompatible shapes: (80, 256, 1, 1) in the checkpoint but (2, 256, 1, 1) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.mask_head.predictor.bias' to the model due to incompatible shapes: (80,) in the checkpoint but (2,) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Some model parameters or buffers are not found in the checkpoint:
# roi_heads.box_predictor.bbox_pred.{bias, weight}
# roi_heads.box_predictor.cls_score.{bias, weight}
# roi_heads.mask_head.predictor.{bias, weight}
# WARNING [07/24 11:07:20 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [07/24 11:07:20 d2.data.datasets.coco]: Loaded 258 images in COCO format from ./BENCHmark-1/train/_annotations.coco.json
# [07/24 11:07:20 d2.data.build]: Removed 0 images with no usable annotations. 258 images left.
# [07/24 11:07:20 d2.data.build]: Distribution of instances among all 2 categories:
# |  category  | #instances   |  category  | #instances   |
# |:----------:|:-------------|:----------:|:-------------|
# |  benches   | 0            |  benches   | 434          |
# |            |              |            |              |
# |   total    | 434          |            |              |
# [07/24 11:07:20 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(640, 672, 704, 736, 768, 800), max_size=1333, sample_style='choice'), RandomFlip()]
# [07/24 11:07:20 d2.data.build]: Using training sampler TrainingSampler
# [07/24 11:07:20 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [07/24 11:07:20 d2.data.common]: Serializing 258 elements to byte tensors and concatenating them all ...
# [07/24 11:07:20 d2.data.common]: Serialized dataset takes 0.20 MiB
# [07/24 11:07:20 detectron2]: Starting training from iteration 0
# torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3483.)
# [07/24 11:07:30 d2.utils.events]:  iter: 19  total_loss: 1.954  loss_cls: 1.071  loss_box_reg: 0.1552  loss_mask: 0.6951  loss_rpn_cls: 0.01133  loss_rpn_loc: 0.005765     lr: 4.9953e-06  max_mem: 1766M
# [07/24 11:07:41 d2.utils.events]:  eta: 1:28:24  iter: 39  total_loss: 1.84  loss_cls: 0.9156  loss_box_reg: 0.1937  loss_mask: 0.6876  loss_rpn_cls: 0.01486  loss_rpn_loc: 0.008828     lr: 9.9902e-06  max_mem: 1767M
# [07/24 11:07:48 d2.utils.events]:  eta: 0:56:55  iter: 59  total_loss: 1.642  loss_cls: 0.7274  loss_box_reg: 0.1898  loss_mask: 0.6684  loss_rpn_cls: 0.01101  loss_rpn_loc: 0.007414     lr: 1.4985e-05  max_mem: 1767M
# [07/24 11:07:54 d2.utils.events]:  eta: 0:54:35  iter: 79  total_loss: 1.363  loss_cls: 0.5204  loss_box_reg: 0.1656  loss_mask: 0.6451  loss_rpn_cls: 0.005642  loss_rpn_loc: 0.006434     lr: 1.998e-05  max_mem: 1768M
# [07/24 11:08:01 d2.utils.events]:  eta: 0:57:19  iter: 99  total_loss: 1.235  loss_cls: 0.3784  loss_box_reg: 0.183  loss_mask: 0.6229  loss_rpn_cls: 0.01405  loss_rpn_loc: 0.008869     lr: 2.4975e-05  max_mem: 1768M
# [07/24 11:08:08 d2.utils.events]:  eta: 0:55:37  iter: 119  total_loss: 1.005  loss_cls: 0.253  loss_box_reg: 0.1581  loss_mask: 0.5738  loss_rpn_cls: 0.007092  loss_rpn_loc: 0.005196     lr: 2.997e-05  max_mem: 1768M
# [07/24 11:08:15 d2.utils.events]:  eta: 0:56:39  iter: 139  total_loss: 0.921  loss_cls: 0.2053  loss_box_reg: 0.1529  loss_mask: 0.5592  loss_rpn_cls: 0.006781  loss_rpn_loc: 0.006673     lr: 3.4965e-05  max_mem: 1792M
# [07/24 11:08:22 d2.utils.events]:  eta: 0:58:09  iter: 159  total_loss: 0.8811  loss_cls: 0.1762  loss_box_reg: 0.1671  loss_mask: 0.491  loss_rpn_cls: 0.01022  loss_rpn_loc: 0.008347     lr: 3.996e-05  max_mem: 1792M
# [07/24 11:08:29 d2.utils.events]:  eta: 0:57:57  iter: 179  total_loss: 0.8925  loss_cls: 0.1938  loss_box_reg: 0.1917  loss_mask: 0.4739  loss_rpn_cls: 0.006201  loss_rpn_loc: 0.007172     lr: 4.4955e-05  max_mem: 1792M
# [07/24 11:08:36 d2.utils.events]:  eta: 0:54:02  iter: 199  total_loss: 0.7879  loss_cls: 0.1511  loss_box_reg: 0.16  loss_mask: 0.4001  loss_rpn_cls: 0.02469  loss_rpn_loc: 0.007643     lr: 4.995e-05  max_mem: 1792M
# [07/24 11:08:43 d2.utils.events]:  eta: 0:58:17  iter: 219  total_loss: 0.677  loss_cls: 0.1485  loss_box_reg: 0.1589  loss_mask: 0.3369  loss_rpn_cls: 0.004294  loss_rpn_loc: 0.005765     lr: 5.4945e-05  max_mem: 1792M
# [07/24 11:08:50 d2.utils.events]:  eta: 0:56:56  iter: 239  total_loss: 0.6959  loss_cls: 0.1443  loss_box_reg: 0.1821  loss_mask: 0.3171  loss_rpn_cls: 0.0165  loss_rpn_loc: 0.007835     lr: 5.994e-05  max_mem: 1792M
# [07/24 11:08:56 d2.utils.events]:  eta: 0:54:55  iter: 259  total_loss: 0.5635  loss_cls: 0.1203  loss_box_reg: 0.1594  loss_mask: 0.2778  loss_rpn_cls: 0.008123  loss_rpn_loc: 0.004587     lr: 6.4935e-05  max_mem: 1792M
# [07/24 11:09:04 d2.utils.events]:  eta: 0:58:17  iter: 279  total_loss: 0.5644  loss_cls: 0.1286  loss_box_reg: 0.1822  loss_mask: 0.2453  loss_rpn_cls: 0.01223  loss_rpn_loc: 0.005207     lr: 6.993e-05  max_mem: 1792M
# [07/24 11:09:11 d2.utils.events]:  eta: 0:56:50  iter: 299  total_loss: 0.5787  loss_cls: 0.1233  loss_box_reg: 0.1789  loss_mask: 0.2511  loss_rpn_cls: 0.003058  loss_rpn_loc: 0.005863     lr: 7.4925e-05  max_mem: 1792M
# [07/24 11:09:18 d2.utils.events]:  eta: 0:57:10  iter: 319  total_loss: 0.5468  loss_cls: 0.108  loss_box_reg: 0.1717  loss_mask: 0.2541  loss_rpn_cls: 0.006088  loss_rpn_loc: 0.006116     lr: 7.992e-05  max_mem: 1792M
# [07/24 11:09:25 d2.utils.events]:  eta: 0:54:57  iter: 339  total_loss: 0.4529  loss_cls: 0.09808  loss_box_reg: 0.1688  loss_mask: 0.1792  loss_rpn_cls: 0.009371  loss_rpn_loc: 0.004885     lr: 8.4915e-05  max_mem: 1792M
# [07/24 11:09:32 d2.utils.events]:  eta: 0:57:38  iter: 359  total_loss: 0.5698  loss_cls: 0.1017  loss_box_reg: 0.1772  loss_mask: 0.2224  loss_rpn_cls: 0.01034  loss_rpn_loc: 0.006839     lr: 8.991e-05  max_mem: 1792M
# [07/24 11:09:39 d2.utils.events]:  eta: 0:56:04  iter: 379  total_loss: 0.4109  loss_cls: 0.07884  loss_box_reg: 0.1524  loss_mask: 0.1819  loss_rpn_cls: 0.008561  loss_rpn_loc: 0.00414     lr: 9.4905e-05  max_mem: 1792M
# [07/24 11:09:46 d2.utils.events]:  eta: 0:58:16  iter: 399  total_loss: 0.3788  loss_cls: 0.07841  loss_box_reg: 0.1441  loss_mask: 0.1732  loss_rpn_cls: 0.008216  loss_rpn_loc: 0.004108     lr: 9.99e-05  max_mem: 1792M
# [07/24 11:09:53 d2.utils.events]:  eta: 0:57:35  iter: 419  total_loss: 0.3858  loss_cls: 0.07019  loss_box_reg: 0.1468  loss_mask: 0.1849  loss_rpn_cls: 0.003223  loss_rpn_loc: 0.005427     lr: 0.0001049  max_mem: 1817M
# [07/24 11:10:00 d2.utils.events]:  eta: 0:57:34  iter: 439  total_loss: 0.4574  loss_cls: 0.08133  loss_box_reg: 0.1407  loss_mask: 0.2011  loss_rpn_cls: 0.01434  loss_rpn_loc: 0.006225     lr: 0.00010989  max_mem: 1817M
# [07/24 11:10:08 d2.utils.events]:  eta: 0:58:30  iter: 459  total_loss: 0.4272  loss_cls: 0.08758  loss_box_reg: 0.144  loss_mask: 0.1841  loss_rpn_cls: 0.005919  loss_rpn_loc: 0.005609     lr: 0.00011489  max_mem: 1817M
# [07/24 11:10:15 d2.utils.events]:  eta: 0:56:47  iter: 479  total_loss: 0.3814  loss_cls: 0.05514  loss_box_reg: 0.1341  loss_mask: 0.1849  loss_rpn_cls: 0.003403  loss_rpn_loc: 0.005505     lr: 0.00011988  max_mem: 1817M
# [07/24 11:10:22 d2.utils.events]:  eta: 0:57:38  iter: 499  total_loss: 0.5119  loss_cls: 0.08296  loss_box_reg: 0.1521  loss_mask: 0.1899  loss_rpn_cls: 0.009222  loss_rpn_loc: 0.007847     lr: 0.00012488  max_mem: 1817M
# [07/24 11:10:29 d2.utils.events]:  eta: 0:55:30  iter: 519  total_loss: 0.2962  loss_cls: 0.04939  loss_box_reg: 0.09859  loss_mask: 0.1625  loss_rpn_cls: 0.004196  loss_rpn_loc: 0.004155     lr: 0.00012987  max_mem: 1817M
# [07/24 11:10:37 d2.utils.events]:  eta: 0:58:05  iter: 539  total_loss: 0.2961  loss_cls: 0.04698  loss_box_reg: 0.1211  loss_mask: 0.151  loss_rpn_cls: 0.001744  loss_rpn_loc: 0.003975     lr: 0.00013487  max_mem: 1817M
# [07/24 11:10:44 d2.utils.events]:  eta: 0:57:09  iter: 559  total_loss: 0.4359  loss_cls: 0.07226  loss_box_reg: 0.1254  loss_mask: 0.1867  loss_rpn_cls: 0.01102  loss_rpn_loc: 0.00705     lr: 0.00013986  max_mem: 1817M
# [07/24 11:10:51 d2.utils.events]:  eta: 0:56:01  iter: 579  total_loss: 0.3277  loss_cls: 0.04555  loss_box_reg: 0.1015  loss_mask: 0.1465  loss_rpn_cls: 0.005421  loss_rpn_loc: 0.005165     lr: 0.00014486  max_mem: 1817M
# [07/24 11:10:58 d2.utils.events]:  eta: 0:54:52  iter: 599  total_loss: 0.354  loss_cls: 0.05501  loss_box_reg: 0.1069  loss_mask: 0.1679  loss_rpn_cls: 0.01384  loss_rpn_loc: 0.009146     lr: 0.00014985  max_mem: 1817M
# [07/24 11:11:06 d2.utils.events]:  eta: 0:58:29  iter: 619  total_loss: 0.3263  loss_cls: 0.05015  loss_box_reg: 0.09872  loss_mask: 0.1546  loss_rpn_cls: 0.01046  loss_rpn_loc: 0.005327     lr: 0.00015485  max_mem: 1817M
# [07/24 11:11:13 d2.utils.events]:  eta: 0:58:42  iter: 639  total_loss: 0.2368  loss_cls: 0.04212  loss_box_reg: 0.07835  loss_mask: 0.1181  loss_rpn_cls: 0.003034  loss_rpn_loc: 0.003627     lr: 0.00015984  max_mem: 1817M
# [07/24 11:11:20 d2.utils.events]:  eta: 0:57:05  iter: 659  total_loss: 0.2722  loss_cls: 0.04076  loss_box_reg: 0.06234  loss_mask: 0.1509  loss_rpn_cls: 0.008049  loss_rpn_loc: 0.005253     lr: 0.00016484  max_mem: 1817M
# [07/24 11:11:28 d2.utils.events]:  eta: 0:58:25  iter: 679  total_loss: 0.3172  loss_cls: 0.04801  loss_box_reg: 0.08773  loss_mask: 0.1378  loss_rpn_cls: 0.003545  loss_rpn_loc: 0.005032     lr: 0.00016983  max_mem: 1817M
# [07/24 11:11:35 d2.utils.events]:  eta: 0:58:09  iter: 699  total_loss: 0.2366  loss_cls: 0.04835  loss_box_reg: 0.07615  loss_mask: 0.1282  loss_rpn_cls: 0.003031  loss_rpn_loc: 0.004735     lr: 0.00017483  max_mem: 1817M
# [07/24 11:11:43 d2.utils.events]:  eta: 0:55:12  iter: 719  total_loss: 0.2813  loss_cls: 0.04398  loss_box_reg: 0.07903  loss_mask: 0.1555  loss_rpn_cls: 0.003755  loss_rpn_loc: 0.004704     lr: 0.00017982  max_mem: 1817M
# [07/24 11:11:50 d2.utils.events]:  eta: 0:56:59  iter: 739  total_loss: 0.2806  loss_cls: 0.04611  loss_box_reg: 0.06062  loss_mask: 0.142  loss_rpn_cls: 0.003692  loss_rpn_loc: 0.005569     lr: 0.00018482  max_mem: 1817M
# [07/24 11:11:58 d2.utils.events]:  eta: 0:59:17  iter: 759  total_loss: 0.373  loss_cls: 0.0732  loss_box_reg: 0.09443  loss_mask: 0.1791  loss_rpn_cls: 0.005313  loss_rpn_loc: 0.005075     lr: 0.00018981  max_mem: 1817M
# [07/24 11:12:05 d2.utils.events]:  eta: 0:56:01  iter: 779  total_loss: 0.2214  loss_cls: 0.03632  loss_box_reg: 0.04503  loss_mask: 0.1108  loss_rpn_cls: 0.004679  loss_rpn_loc: 0.003463     lr: 0.00019481  max_mem: 1817M
# [07/24 11:12:13 d2.utils.events]:  eta: 0:58:20  iter: 799  total_loss: 0.3315  loss_cls: 0.05524  loss_box_reg: 0.08051  loss_mask: 0.1517  loss_rpn_cls: 0.003188  loss_rpn_loc: 0.005755     lr: 0.0001998  max_mem: 1817M
# Loss has not improved for 100 iterations
# [07/24 11:12:20 d2.utils.events]:  eta: 0:57:59  iter: 819  total_loss: 0.2652  loss_cls: 0.05303  loss_box_reg: 0.07336  loss_mask: 0.1479  loss_rpn_cls: 0.01303  loss_rpn_loc: 0.005776     lr: 0.0002048  max_mem: 1817M
# [07/24 11:12:28 d2.utils.events]:  eta: 0:56:37  iter: 839  total_loss: 0.2627  loss_cls: 0.04409  loss_box_reg: 0.07027  loss_mask: 0.1314  loss_rpn_cls: 0.003196  loss_rpn_loc: 0.003691     lr: 0.00020979  max_mem: 1817M
# [07/24 11:12:35 d2.utils.events]:  eta: 0:56:10  iter: 859  total_loss: 0.2864  loss_cls: 0.04322  loss_box_reg: 0.09079  loss_mask: 0.1466  loss_rpn_cls: 0.005206  loss_rpn_loc: 0.004553     lr: 0.00021479  max_mem: 1817M
# [07/24 11:12:42 d2.utils.events]:  eta: 0:54:41  iter: 879  total_loss: 0.2121  loss_cls: 0.03978  loss_box_reg: 0.04457  loss_mask: 0.1141  loss_rpn_cls: 0.002972  loss_rpn_loc: 0.005672     lr: 0.00021978  max_mem: 1817M
# [07/24 11:12:50 d2.utils.events]:  eta: 0:57:10  iter: 899  total_loss: 0.1849  loss_cls: 0.03547  loss_box_reg: 0.05656  loss_mask: 0.09982  loss_rpn_cls: 0.001397  loss_rpn_loc: 0.005402     lr: 0.00022478  max_mem: 1817M
# [07/24 11:12:57 d2.utils.events]:  eta: 0:56:55  iter: 919  total_loss: 0.2479  loss_cls: 0.04549  loss_box_reg: 0.06598  loss_mask: 0.1391  loss_rpn_cls: 0.002496  loss_rpn_loc: 0.004361     lr: 0.00022977  max_mem: 1817M
# [07/24 11:13:05 d2.utils.events]:  eta: 0:56:24  iter: 939  total_loss: 0.23  loss_cls: 0.03868  loss_box_reg: 0.06166  loss_mask: 0.113  loss_rpn_cls: 0.002761  loss_rpn_loc: 0.003203     lr: 0.00023477  max_mem: 1817M
# [07/24 11:13:12 d2.utils.events]:  eta: 0:56:28  iter: 959  total_loss: 0.1803  loss_cls: 0.02741  loss_box_reg: 0.0449  loss_mask: 0.1006  loss_rpn_cls: 0.001116  loss_rpn_loc: 0.003712     lr: 0.00023976  max_mem: 1817M
# [07/24 11:13:20 d2.utils.events]:  eta: 0:56:42  iter: 979  total_loss: 0.2242  loss_cls: 0.03327  loss_box_reg: 0.04756  loss_mask: 0.1241  loss_rpn_cls: 0.003411  loss_rpn_loc: 0.003871     lr: 0.00024476  max_mem: 1817M
# [07/24 11:13:28 d2.utils.events]:  eta: 0:58:22  iter: 999  total_loss: 0.3068  loss_cls: 0.04536  loss_box_reg: 0.07722  loss_mask: 0.1439  loss_rpn_cls: 0.005466  loss_rpn_loc: 0.004404     lr: 0.00024975  max_mem: 1817M
# [07/24 11:13:35 d2.utils.events]:  eta: 0:55:13  iter: 1019  total_loss: 0.1573  loss_cls: 0.02854  loss_box_reg: 0.03496  loss_mask: 0.1028  loss_rpn_cls: 0.001418  loss_rpn_loc: 0.004708     lr: 0.00025  max_mem: 1817M
# [07/24 11:13:42 d2.utils.events]:  eta: 0:55:53  iter: 1039  total_loss: 0.2542  loss_cls: 0.03803  loss_box_reg: 0.05026  loss_mask: 0.1356  loss_rpn_cls: 0.003197  loss_rpn_loc: 0.0045     lr: 0.00025  max_mem: 1817M
# Loss has not improved for 100 iterations
# [07/24 11:13:50 d2.utils.events]:  eta: 0:57:11  iter: 1059  total_loss: 0.2186  loss_cls: 0.03409  loss_box_reg: 0.04321  loss_mask: 0.1154  loss_rpn_cls: 0.001018  loss_rpn_loc: 0.003967     lr: 0.00025  max_mem: 1817M
# [07/24 11:13:58 d2.utils.events]:  eta: 0:56:15  iter: 1079  total_loss: 0.1618  loss_cls: 0.02831  loss_box_reg: 0.03994  loss_mask: 0.1036  loss_rpn_cls: 0.002087  loss_rpn_loc: 0.004198     lr: 0.00025  max_mem: 1817M
# [07/24 11:14:05 d2.utils.events]:  eta: 0:56:26  iter: 1099  total_loss: 0.1876  loss_cls: 0.03038  loss_box_reg: 0.04551  loss_mask: 0.1117  loss_rpn_cls: 0.002269  loss_rpn_loc: 0.003551     lr: 0.00025  max_mem: 1817M
# [07/24 11:14:12 d2.utils.events]:  eta: 0:53:44  iter: 1119  total_loss: 0.1844  loss_cls: 0.02937  loss_box_reg: 0.03681  loss_mask: 0.1105  loss_rpn_cls: 0.001418  loss_rpn_loc: 0.004029     lr: 0.00025  max_mem: 1817M
# [07/24 11:14:20 d2.utils.events]:  eta: 0:55:04  iter: 1139  total_loss: 0.2521  loss_cls: 0.03698  loss_box_reg: 0.06534  loss_mask: 0.1252  loss_rpn_cls: 0.00211  loss_rpn_loc: 0.004041     lr: 0.00025  max_mem: 1838M
# [07/24 11:14:27 d2.utils.events]:  eta: 0:54:07  iter: 1159  total_loss: 0.1644  loss_cls: 0.02525  loss_box_reg: 0.03958  loss_mask: 0.09981  loss_rpn_cls: 0.001713  loss_rpn_loc: 0.004245     lr: 0.00025  max_mem: 1838M
# [07/24 11:14:35 d2.utils.events]:  eta: 0:56:06  iter: 1179  total_loss: 0.1964  loss_cls: 0.03577  loss_box_reg: 0.05429  loss_mask: 0.1105  loss_rpn_cls: 0.001989  loss_rpn_loc: 0.004292     lr: 0.00025  max_mem: 1838M
# [07/24 11:14:42 d2.utils.events]:  eta: 0:54:58  iter: 1199  total_loss: 0.1663  loss_cls: 0.02612  loss_box_reg: 0.03687  loss_mask: 0.09522  loss_rpn_cls: 0.001904  loss_rpn_loc: 0.004919     lr: 0.00025  max_mem: 1838M
# [07/24 11:14:50 d2.utils.events]:  eta: 0:55:04  iter: 1219  total_loss: 0.1612  loss_cls: 0.0275  loss_box_reg: 0.03027  loss_mask: 0.09492  loss_rpn_cls: 0.002443  loss_rpn_loc: 0.003235     lr: 0.00025  max_mem: 1838M
# [07/24 11:14:57 d2.utils.events]:  eta: 0:52:56  iter: 1239  total_loss: 0.1742  loss_cls: 0.02514  loss_box_reg: 0.03977  loss_mask: 0.1005  loss_rpn_cls: 0.001013  loss_rpn_loc: 0.003811     lr: 0.00025  max_mem: 1838M
# [07/24 11:15:04 d2.utils.events]:  eta: 0:50:55  iter: 1259  total_loss: 0.164  loss_cls: 0.02851  loss_box_reg: 0.04143  loss_mask: 0.09671  loss_rpn_cls: 0.001148  loss_rpn_loc: 0.004886     lr: 0.00025  max_mem: 1838M
# [07/24 11:15:12 d2.utils.events]:  eta: 0:54:42  iter: 1279  total_loss: 0.2302  loss_cls: 0.03409  loss_box_reg: 0.05195  loss_mask: 0.1225  loss_rpn_cls: 0.001573  loss_rpn_loc: 0.004424     lr: 0.00025  max_mem: 1838M
# [07/24 11:15:19 d2.utils.events]:  eta: 0:54:49  iter: 1299  total_loss: 0.2657  loss_cls: 0.04513  loss_box_reg: 0.0723  loss_mask: 0.1508  loss_rpn_cls: 0.001944  loss_rpn_loc: 0.004954     lr: 0.00025  max_mem: 1838M
# Loss has not improved for 100 iterations
# [07/24 11:15:27 d2.utils.events]:  eta: 0:55:34  iter: 1319  total_loss: 0.2139  loss_cls: 0.0307  loss_box_reg: 0.05281  loss_mask: 0.1144  loss_rpn_cls: 0.001383  loss_rpn_loc: 0.005298     lr: 0.00025  max_mem: 1838M
# [07/24 11:15:34 d2.utils.events]:  eta: 0:52:03  iter: 1339  total_loss: 0.1277  loss_cls: 0.01915  loss_box_reg: 0.02719  loss_mask: 0.0763  loss_rpn_cls: 0.000476  loss_rpn_loc: 0.002168     lr: 0.00025  max_mem: 1838M
# [07/24 11:15:42 d2.utils.events]:  eta: 0:53:13  iter: 1359  total_loss: 0.1623  loss_cls: 0.02421  loss_box_reg: 0.03503  loss_mask: 0.08897  loss_rpn_cls: 0.00105  loss_rpn_loc: 0.003567     lr: 0.00025  max_mem: 1838M
# [07/24 11:15:49 d2.utils.events]:  eta: 0:53:31  iter: 1379  total_loss: 0.2119  loss_cls: 0.03014  loss_box_reg: 0.05248  loss_mask: 0.1059  loss_rpn_cls: 0.0009516  loss_rpn_loc: 0.004336     lr: 0.00025  max_mem: 1838M
# [07/24 11:15:57 d2.utils.events]:  eta: 0:53:46  iter: 1399  total_loss: 0.1658  loss_cls: 0.02697  loss_box_reg: 0.03898  loss_mask: 0.1056  loss_rpn_cls: 0.0006447  loss_rpn_loc: 0.004273     lr: 0.00025  max_mem: 1838M
# Loss has not improved for 200 iterations
# [07/24 11:16:04 d2.utils.events]:  eta: 0:53:36  iter: 1419  total_loss: 0.2162  loss_cls: 0.0253  loss_box_reg: 0.03718  loss_mask: 0.1211  loss_rpn_cls: 0.0005113  loss_rpn_loc: 0.003677     lr: 0.00025  max_mem: 1838M
# [07/24 11:16:11 d2.utils.events]:  eta: 0:52:23  iter: 1439  total_loss: 0.1688  loss_cls: 0.02809  loss_box_reg: 0.04748  loss_mask: 0.09789  loss_rpn_cls: 0.0009771  loss_rpn_loc: 0.003562     lr: 0.00025  max_mem: 1838M
# [07/24 11:16:19 d2.utils.events]:  eta: 0:53:23  iter: 1459  total_loss: 0.2003  loss_cls: 0.03395  loss_box_reg: 0.04847  loss_mask: 0.1039  loss_rpn_cls: 0.001924  loss_rpn_loc: 0.003596     lr: 0.00025  max_mem: 1838M
# [07/24 11:16:26 d2.utils.events]:  eta: 0:52:38  iter: 1479  total_loss: 0.1536  loss_cls: 0.02285  loss_box_reg: 0.03024  loss_mask: 0.09814  loss_rpn_cls: 0.0004588  loss_rpn_loc: 0.003237     lr: 0.00025  max_mem: 1838M
# [07/24 11:16:34 d2.utils.events]:  eta: 0:52:54  iter: 1499  total_loss: 0.15  loss_cls: 0.02323  loss_box_reg: 0.03167  loss_mask: 0.0938  loss_rpn_cls: 0.001538  loss_rpn_loc: 0.00338     lr: 0.00025  max_mem: 1838M
# [07/24 11:16:41 d2.utils.events]:  eta: 0:53:44  iter: 1519  total_loss: 0.1768  loss_cls: 0.0365  loss_box_reg: 0.04597  loss_mask: 0.0956  loss_rpn_cls: 0.0008711  loss_rpn_loc: 0.004446     lr: 0.00025  max_mem: 1838M
# [07/24 11:16:49 d2.utils.events]:  eta: 0:53:12  iter: 1539  total_loss: 0.1367  loss_cls: 0.02728  loss_box_reg: 0.03579  loss_mask: 0.08792  loss_rpn_cls: 0.001462  loss_rpn_loc: 0.004209     lr: 0.00025  max_mem: 1838M
# Loss has not improved for 100 iterations
# [07/24 11:16:56 d2.utils.events]:  eta: 0:52:25  iter: 1559  total_loss: 0.1467  loss_cls: 0.0249  loss_box_reg: 0.03552  loss_mask: 0.08837  loss_rpn_cls: 0.00131  loss_rpn_loc: 0.003234     lr: 0.00025  max_mem: 1838M
# [07/24 11:17:04 d2.utils.events]:  eta: 0:53:01  iter: 1579  total_loss: 0.15  loss_cls: 0.02047  loss_box_reg: 0.0344  loss_mask: 0.09553  loss_rpn_cls: 0.0009074  loss_rpn_loc: 0.003649     lr: 0.00025  max_mem: 1838M
# [07/24 11:17:11 d2.utils.events]:  eta: 0:52:25  iter: 1599  total_loss: 0.1592  loss_cls: 0.02569  loss_box_reg: 0.03792  loss_mask: 0.08772  loss_rpn_cls: 0.001131  loss_rpn_loc: 0.004475     lr: 0.00025  max_mem: 1838M
# [07/24 11:17:19 d2.utils.events]:  eta: 0:55:20  iter: 1619  total_loss: 0.159  loss_cls: 0.03153  loss_box_reg: 0.04005  loss_mask: 0.0947  loss_rpn_cls: 0.001368  loss_rpn_loc: 0.004162     lr: 0.00025  max_mem: 1838M
# [07/24 11:17:27 d2.utils.events]:  eta: 0:53:03  iter: 1639  total_loss: 0.1838  loss_cls: 0.02174  loss_box_reg: 0.03978  loss_mask: 0.1009  loss_rpn_cls: 0.0005165  loss_rpn_loc: 0.003282     lr: 0.00025  max_mem: 1838M
# Loss has not improved for 200 iterations
# [07/24 11:17:34 d2.utils.events]:  eta: 0:49:51  iter: 1659  total_loss: 0.1419  loss_cls: 0.02858  loss_box_reg: 0.03564  loss_mask: 0.09297  loss_rpn_cls: 0.00171  loss_rpn_loc: 0.004159     lr: 0.00025  max_mem: 1838M
# [07/24 11:17:42 d2.utils.events]:  eta: 0:52:29  iter: 1679  total_loss: 0.1826  loss_cls: 0.02506  loss_box_reg: 0.03833  loss_mask: 0.09784  loss_rpn_cls: 0.0007381  loss_rpn_loc: 0.002917     lr: 0.00025  max_mem: 1838M
# [07/24 11:17:49 d2.utils.events]:  eta: 0:52:27  iter: 1699  total_loss: 0.1824  loss_cls: 0.02367  loss_box_reg: 0.04728  loss_mask: 0.09871  loss_rpn_cls: 0.0005088  loss_rpn_loc: 0.004754     lr: 0.00025  max_mem: 1838M
# [07/24 11:17:57 d2.utils.events]:  eta: 0:51:07  iter: 1719  total_loss: 0.125  loss_cls: 0.02083  loss_box_reg: 0.03462  loss_mask: 0.07788  loss_rpn_cls: 0.0009492  loss_rpn_loc: 0.003368     lr: 0.00025  max_mem: 1838M
# [07/24 11:18:04 d2.utils.events]:  eta: 0:51:28  iter: 1739  total_loss: 0.1382  loss_cls: 0.02535  loss_box_reg: 0.03819  loss_mask: 0.08607  loss_rpn_cls: 0.001176  loss_rpn_loc: 0.003549     lr: 0.00025  max_mem: 1838M
# [07/24 11:18:12 d2.utils.events]:  eta: 0:52:21  iter: 1759  total_loss: 0.1205  loss_cls: 0.02079  loss_box_reg: 0.02848  loss_mask: 0.07488  loss_rpn_cls: 0.0002255  loss_rpn_loc: 0.002529     lr: 0.00025  max_mem: 1838M
# [07/24 11:18:19 d2.utils.events]:  eta: 0:50:09  iter: 1779  total_loss: 0.201  loss_cls: 0.02435  loss_box_reg: 0.05677  loss_mask: 0.1042  loss_rpn_cls: 0.0009873  loss_rpn_loc: 0.004     lr: 0.00025  max_mem: 1838M
# [07/24 11:18:27 d2.utils.events]:  eta: 0:52:28  iter: 1799  total_loss: 0.1515  loss_cls: 0.02176  loss_box_reg: 0.04301  loss_mask: 0.1006  loss_rpn_cls: 0.000702  loss_rpn_loc: 0.003101     lr: 0.00025  max_mem: 1838M
# Loss has not improved for 100 iterations
# [07/24 11:18:34 d2.utils.events]:  eta: 0:50:28  iter: 1819  total_loss: 0.1524  loss_cls: 0.02124  loss_box_reg: 0.038  loss_mask: 0.104  loss_rpn_cls: 0.0007386  loss_rpn_loc: 0.00474     lr: 0.00025  max_mem: 1838M
# [07/24 11:18:42 d2.utils.events]:  eta: 0:49:52  iter: 1839  total_loss: 0.1299  loss_cls: 0.01919  loss_box_reg: 0.02586  loss_mask: 0.07671  loss_rpn_cls: 0.000453  loss_rpn_loc: 0.002987     lr: 0.00025  max_mem: 1838M
# [07/24 11:18:49 d2.utils.events]:  eta: 0:50:57  iter: 1859  total_loss: 0.159  loss_cls: 0.02501  loss_box_reg: 0.03522  loss_mask: 0.08524  loss_rpn_cls: 0.0006399  loss_rpn_loc: 0.002964     lr: 0.00025  max_mem: 1838M
# [07/24 11:18:57 d2.utils.events]:  eta: 0:50:27  iter: 1879  total_loss: 0.1752  loss_cls: 0.02826  loss_box_reg: 0.05372  loss_mask: 0.0778  loss_rpn_cls: 0.0006891  loss_rpn_loc: 0.004141     lr: 0.00025  max_mem: 1838M
# [07/24 11:19:04 d2.utils.events]:  eta: 0:49:32  iter: 1899  total_loss: 0.1338  loss_cls: 0.02018  loss_box_reg: 0.02893  loss_mask: 0.081  loss_rpn_cls: 0.0004012  loss_rpn_loc: 0.003018     lr: 0.00025  max_mem: 1838M
# Loss has not improved for 200 iterations
# [07/24 11:19:11 d2.utils.events]:  eta: 0:49:43  iter: 1919  total_loss: 0.1301  loss_cls: 0.01904  loss_box_reg: 0.03067  loss_mask: 0.08162  loss_rpn_cls: 0.0003567  loss_rpn_loc: 0.003586     lr: 0.00025  max_mem: 1838M
# [07/24 11:19:19 d2.utils.events]:  eta: 0:50:18  iter: 1939  total_loss: 0.2074  loss_cls: 0.02714  loss_box_reg: 0.04735  loss_mask: 0.1036  loss_rpn_cls: 0.001161  loss_rpn_loc: 0.004439     lr: 0.00025  max_mem: 1848M
# [07/24 11:19:26 d2.utils.events]:  eta: 0:50:36  iter: 1959  total_loss: 0.1254  loss_cls: 0.01779  loss_box_reg: 0.02849  loss_mask: 0.07337  loss_rpn_cls: 0.0002912  loss_rpn_loc: 0.002768     lr: 0.00025  max_mem: 1848M
# [07/24 11:19:34 d2.utils.events]:  eta: 0:51:03  iter: 1979  total_loss: 0.1533  loss_cls: 0.02997  loss_box_reg: 0.03779  loss_mask: 0.08645  loss_rpn_cls: 0.001179  loss_rpn_loc: 0.00432     lr: 0.00025  max_mem: 1862M
# [07/24 11:19:41 d2.utils.events]:  eta: 0:49:18  iter: 1999  total_loss: 0.1371  loss_cls: 0.02251  loss_box_reg: 0.03108  loss_mask: 0.07749  loss_rpn_cls: 0.0003383  loss_rpn_loc: 0.003577     lr: 0.00025  max_mem: 1862M
# [07/24 11:19:49 d2.utils.events]:  eta: 0:50:31  iter: 2019  total_loss: 0.181  loss_cls: 0.0221  loss_box_reg: 0.03929  loss_mask: 0.09345  loss_rpn_cls: 0.0007748  loss_rpn_loc: 0.00406     lr: 0.00025  max_mem: 1919M
# [07/24 11:19:57 d2.utils.events]:  eta: 0:50:39  iter: 2039  total_loss: 0.1443  loss_cls: 0.02407  loss_box_reg: 0.03881  loss_mask: 0.07817  loss_rpn_cls: 0.0002369  loss_rpn_loc: 0.002423     lr: 0.00025  max_mem: 1919M
# Loss has not improved for 100 iterations
# [07/24 11:20:04 d2.utils.events]:  eta: 0:50:34  iter: 2059  total_loss: 0.1509  loss_cls: 0.02401  loss_box_reg: 0.03022  loss_mask: 0.0898  loss_rpn_cls: 0.0006397  loss_rpn_loc: 0.002923     lr: 0.00025  max_mem: 1919M
# [07/24 11:20:12 d2.utils.events]:  eta: 0:49:03  iter: 2079  total_loss: 0.1208  loss_cls: 0.01765  loss_box_reg: 0.03048  loss_mask: 0.07953  loss_rpn_cls: 0.0003596  loss_rpn_loc: 0.002794     lr: 0.00025  max_mem: 1919M
# [07/24 11:20:19 d2.utils.events]:  eta: 0:48:52  iter: 2099  total_loss: 0.1372  loss_cls: 0.02016  loss_box_reg: 0.03364  loss_mask: 0.08822  loss_rpn_cls: 0.0004764  loss_rpn_loc: 0.003643     lr: 0.00025  max_mem: 1919M
# [07/24 11:20:27 d2.utils.events]:  eta: 0:49:54  iter: 2119  total_loss: 0.149  loss_cls: 0.02274  loss_box_reg: 0.03472  loss_mask: 0.08443  loss_rpn_cls: 0.0003691  loss_rpn_loc: 0.005003     lr: 0.00025  max_mem: 1919M
# [07/24 11:20:34 d2.utils.events]:  eta: 0:48:23  iter: 2139  total_loss: 0.1062  loss_cls: 0.01817  loss_box_reg: 0.02283  loss_mask: 0.067  loss_rpn_cls: 0.0001965  loss_rpn_loc: 0.002282     lr: 0.00025  max_mem: 1919M
# [07/24 11:20:42 d2.utils.events]:  eta: 0:50:17  iter: 2159  total_loss: 0.1336  loss_cls: 0.0178  loss_box_reg: 0.03297  loss_mask: 0.08232  loss_rpn_cls: 0.0001338  loss_rpn_loc: 0.002757     lr: 0.00025  max_mem: 1919M
# [07/24 11:20:49 d2.utils.events]:  eta: 0:48:36  iter: 2179  total_loss: 0.2193  loss_cls: 0.02905  loss_box_reg: 0.06496  loss_mask: 0.1115  loss_rpn_cls: 0.001146  loss_rpn_loc: 0.005703     lr: 0.00025  max_mem: 1919M
# Loss has not improved for 100 iterations
# [07/24 11:20:57 d2.utils.events]:  eta: 0:48:41  iter: 2199  total_loss: 0.1439  loss_cls: 0.0212  loss_box_reg: 0.03597  loss_mask: 0.08126  loss_rpn_cls: 0.0005653  loss_rpn_loc: 0.003004     lr: 0.00025  max_mem: 1919M
# [07/24 11:21:04 d2.utils.events]:  eta: 0:49:27  iter: 2219  total_loss: 0.1263  loss_cls: 0.01494  loss_box_reg: 0.02645  loss_mask: 0.07305  loss_rpn_cls: 0.000297  loss_rpn_loc: 0.002482     lr: 0.00025  max_mem: 1919M
# [07/24 11:21:12 d2.utils.events]:  eta: 0:49:14  iter: 2239  total_loss: 0.1281  loss_cls: 0.02182  loss_box_reg: 0.03213  loss_mask: 0.07283  loss_rpn_cls: 0.0002505  loss_rpn_loc: 0.002862     lr: 0.00025  max_mem: 1919M
# [07/24 11:21:20 d2.utils.events]:  eta: 0:50:09  iter: 2259  total_loss: 0.1913  loss_cls: 0.02796  loss_box_reg: 0.05082  loss_mask: 0.1015  loss_rpn_cls: 0.0009697  loss_rpn_loc: 0.004317     lr: 0.00025  max_mem: 1919M
# [07/24 11:21:27 d2.utils.events]:  eta: 0:48:24  iter: 2279  total_loss: 0.1341  loss_cls: 0.02084  loss_box_reg: 0.02503  loss_mask: 0.08255  loss_rpn_cls: 0.000117  loss_rpn_loc: 0.003697     lr: 0.00025  max_mem: 1919M
# [07/24 11:21:35 d2.utils.events]:  eta: 0:50:12  iter: 2299  total_loss: 0.1359  loss_cls: 0.02046  loss_box_reg: 0.03143  loss_mask: 0.08184  loss_rpn_cls: 0.0008513  loss_rpn_loc: 0.003084     lr: 0.00025  max_mem: 1919M
# [07/24 11:21:42 d2.utils.events]:  eta: 0:47:24  iter: 2319  total_loss: 0.1372  loss_cls: 0.01859  loss_box_reg: 0.03059  loss_mask: 0.07854  loss_rpn_cls: 0.0004517  loss_rpn_loc: 0.002933     lr: 0.00025  max_mem: 1919M
# [07/24 11:21:50 d2.utils.events]:  eta: 0:49:26  iter: 2339  total_loss: 0.1977  loss_cls: 0.0267  loss_box_reg: 0.04639  loss_mask: 0.1075  loss_rpn_cls: 0.0002994  loss_rpn_loc: 0.003254     lr: 0.00025  max_mem: 1924M
# Loss has not improved for 100 iterations
# [07/24 11:21:58 d2.utils.events]:  eta: 0:48:08  iter: 2359  total_loss: 0.1088  loss_cls: 0.01616  loss_box_reg: 0.02876  loss_mask: 0.06928  loss_rpn_cls: 0.0001871  loss_rpn_loc: 0.003284     lr: 0.00025  max_mem: 1924M
# [07/24 11:22:05 d2.utils.events]:  eta: 0:47:38  iter: 2379  total_loss: 0.1102  loss_cls: 0.01784  loss_box_reg: 0.02197  loss_mask: 0.0705  loss_rpn_cls: 0.0002917  loss_rpn_loc: 0.002924     lr: 0.00025  max_mem: 1924M
# [07/24 11:22:13 d2.utils.events]:  eta: 0:48:03  iter: 2399  total_loss: 0.1454  loss_cls: 0.02039  loss_box_reg: 0.03918  loss_mask: 0.09793  loss_rpn_cls: 0.0003415  loss_rpn_loc: 0.003     lr: 0.00025  max_mem: 1924M
# [07/24 11:22:20 d2.utils.events]:  eta: 0:47:26  iter: 2419  total_loss: 0.1258  loss_cls: 0.02078  loss_box_reg: 0.03149  loss_mask: 0.07673  loss_rpn_cls: 0.0001888  loss_rpn_loc: 0.003578     lr: 0.00025  max_mem: 1924M
# [07/24 11:22:28 d2.utils.events]:  eta: 0:48:45  iter: 2439  total_loss: 0.1843  loss_cls: 0.02432  loss_box_reg: 0.04229  loss_mask: 0.09645  loss_rpn_cls: 0.0001498  loss_rpn_loc: 0.00322     lr: 0.00025  max_mem: 1924M
# [07/24 11:22:36 d2.utils.events]:  eta: 0:48:50  iter: 2459  total_loss: 0.1207  loss_cls: 0.02297  loss_box_reg: 0.03235  loss_mask: 0.07397  loss_rpn_cls: 0.0001954  loss_rpn_loc: 0.004093     lr: 0.00025  max_mem: 1924M
# [07/24 11:22:43 d2.utils.events]:  eta: 0:47:04  iter: 2479  total_loss: 0.1331  loss_cls: 0.01742  loss_box_reg: 0.02696  loss_mask: 0.07701  loss_rpn_cls: 0.0004503  loss_rpn_loc: 0.003215     lr: 0.00025  max_mem: 1924M
# [07/24 11:22:51 d2.utils.events]:  eta: 0:46:03  iter: 2499  total_loss: 0.1101  loss_cls: 0.01399  loss_box_reg: 0.02511  loss_mask: 0.06448  loss_rpn_cls: 0.0001087  loss_rpn_loc: 0.00273     lr: 0.00025  max_mem: 1924M
# [07/24 11:22:58 d2.utils.events]:  eta: 0:47:45  iter: 2519  total_loss: 0.1272  loss_cls: 0.01615  loss_box_reg: 0.02931  loss_mask: 0.08703  loss_rpn_cls: 0.000211  loss_rpn_loc: 0.003588     lr: 0.00025  max_mem: 1924M
# [07/24 11:23:06 d2.utils.events]:  eta: 0:47:16  iter: 2539  total_loss: 0.1454  loss_cls: 0.02325  loss_box_reg: 0.03934  loss_mask: 0.07598  loss_rpn_cls: 0.0004613  loss_rpn_loc: 0.003665     lr: 0.00025  max_mem: 1924M
# Loss has not improved for 100 iterations
# [07/24 11:23:14 d2.utils.events]:  eta: 0:49:07  iter: 2559  total_loss: 0.1612  loss_cls: 0.02387  loss_box_reg: 0.03397  loss_mask: 0.08581  loss_rpn_cls: 0.000189  loss_rpn_loc: 0.002819     lr: 0.00025  max_mem: 1924M
# [07/24 11:23:21 d2.utils.events]:  eta: 0:46:39  iter: 2579  total_loss: 0.1103  loss_cls: 0.02165  loss_box_reg: 0.03163  loss_mask: 0.07122  loss_rpn_cls: 0.0002783  loss_rpn_loc: 0.003628     lr: 0.00025  max_mem: 1924M
# [07/24 11:23:29 d2.utils.events]:  eta: 0:45:32  iter: 2599  total_loss: 0.1131  loss_cls: 0.0164  loss_box_reg: 0.02558  loss_mask: 0.07041  loss_rpn_cls: 0.0004442  loss_rpn_loc: 0.002882     lr: 0.00025  max_mem: 1924M
# [07/24 11:23:37 d2.utils.events]:  eta: 0:47:22  iter: 2619  total_loss: 0.1043  loss_cls: 0.02134  loss_box_reg: 0.02456  loss_mask: 0.0682  loss_rpn_cls: 0.0001422  loss_rpn_loc: 0.002444     lr: 0.00025  max_mem: 1924M
# [07/24 11:23:44 d2.utils.events]:  eta: 0:45:14  iter: 2639  total_loss: 0.1266  loss_cls: 0.01815  loss_box_reg: 0.02894  loss_mask: 0.07227  loss_rpn_cls: 0.0001347  loss_rpn_loc: 0.002933     lr: 0.00025  max_mem: 1924M
# Loss has not improved for 200 iterations
# [07/24 11:23:51 d2.utils.events]:  eta: 0:44:19  iter: 2659  total_loss: 0.1276  loss_cls: 0.02198  loss_box_reg: 0.03289  loss_mask: 0.07258  loss_rpn_cls: 0.0003197  loss_rpn_loc: 0.00305     lr: 0.00025  max_mem: 1924M
# [07/24 11:23:59 d2.utils.events]:  eta: 0:46:11  iter: 2679  total_loss: 0.1479  loss_cls: 0.01783  loss_box_reg: 0.0314  loss_mask: 0.07968  loss_rpn_cls: 0.0009459  loss_rpn_loc: 0.002961     lr: 0.00025  max_mem: 1924M
# [07/24 11:24:07 d2.utils.events]:  eta: 0:47:11  iter: 2699  total_loss: 0.1616  loss_cls: 0.02354  loss_box_reg: 0.03463  loss_mask: 0.09582  loss_rpn_cls: 0.0004448  loss_rpn_loc: 0.003879     lr: 0.00025  max_mem: 1924M
# [07/24 11:24:14 d2.utils.events]:  eta: 0:44:15  iter: 2719  total_loss: 0.1098  loss_cls: 0.01572  loss_box_reg: 0.025  loss_mask: 0.06522  loss_rpn_cls: 0.0006752  loss_rpn_loc: 0.003005     lr: 0.00025  max_mem: 1924M
# [07/24 11:24:22 d2.utils.events]:  eta: 0:47:22  iter: 2739  total_loss: 0.1818  loss_cls: 0.02701  loss_box_reg: 0.04991  loss_mask: 0.09576  loss_rpn_cls: 0.001497  loss_rpn_loc: 0.004289     lr: 0.00025  max_mem: 1924M
# Loss has not improved for 300 iterations
# [07/24 11:24:29 d2.utils.events]:  eta: 0:45:15  iter: 2759  total_loss: 0.1202  loss_cls: 0.01942  loss_box_reg: 0.02698  loss_mask: 0.06939  loss_rpn_cls: 0.0001406  loss_rpn_loc: 0.003314     lr: 0.00025  max_mem: 1924M
# [07/24 11:24:37 d2.utils.events]:  eta: 0:46:09  iter: 2779  total_loss: 0.1113  loss_cls: 0.01881  loss_box_reg: 0.02527  loss_mask: 0.07344  loss_rpn_cls: 0.0001417  loss_rpn_loc: 0.003476     lr: 0.00025  max_mem: 1924M
# [07/24 11:24:45 d2.utils.events]:  eta: 0:46:28  iter: 2799  total_loss: 0.2054  loss_cls: 0.02851  loss_box_reg: 0.05262  loss_mask: 0.1163  loss_rpn_cls: 0.0008323  loss_rpn_loc: 0.004956     lr: 0.00025  max_mem: 1924M
# [07/24 11:24:52 d2.utils.events]:  eta: 0:44:25  iter: 2819  total_loss: 0.1389  loss_cls: 0.0178  loss_box_reg: 0.03016  loss_mask: 0.07732  loss_rpn_cls: 0.0003495  loss_rpn_loc: 0.003317     lr: 0.00025  max_mem: 1924M
# [07/24 11:25:00 d2.utils.events]:  eta: 0:45:24  iter: 2839  total_loss: 0.1124  loss_cls: 0.01857  loss_box_reg: 0.02559  loss_mask: 0.06843  loss_rpn_cls: 5.153e-05  loss_rpn_loc: 0.002546     lr: 0.00025  max_mem: 1924M
# Loss has not improved for 400 iterations
# [07/24 11:25:07 d2.utils.events]:  eta: 0:45:54  iter: 2859  total_loss: 0.1097  loss_cls: 0.01591  loss_box_reg: 0.02323  loss_mask: 0.06126  loss_rpn_cls: 0.0001759  loss_rpn_loc: 0.002639     lr: 0.00025  max_mem: 1924M
# [07/24 11:25:15 d2.utils.events]:  eta: 0:44:49  iter: 2879  total_loss: 0.1509  loss_cls: 0.02097  loss_box_reg: 0.03323  loss_mask: 0.09315  loss_rpn_cls: 0.000186  loss_rpn_loc: 0.003304     lr: 0.00025  max_mem: 1924M
# [07/24 11:25:23 d2.utils.events]:  eta: 0:46:07  iter: 2899  total_loss: 0.1526  loss_cls: 0.02008  loss_box_reg: 0.03086  loss_mask: 0.07979  loss_rpn_cls: 0.0001435  loss_rpn_loc: 0.00334     lr: 0.00025  max_mem: 1924M
# [07/24 11:25:30 d2.utils.events]:  eta: 0:44:29  iter: 2919  total_loss: 0.1614  loss_cls: 0.02231  loss_box_reg: 0.03624  loss_mask: 0.09022  loss_rpn_cls: 0.000354  loss_rpn_loc: 0.003348     lr: 0.00025  max_mem: 1924M
# [07/24 11:25:38 d2.utils.events]:  eta: 0:44:38  iter: 2939  total_loss: 0.105  loss_cls: 0.01619  loss_box_reg: 0.02486  loss_mask: 0.05901  loss_rpn_cls: 0.0001875  loss_rpn_loc: 0.002195     lr: 0.00025  max_mem: 1924M
# Loss has not improved for 100 iterations
# [07/24 11:25:45 d2.utils.events]:  eta: 0:43:28  iter: 2959  total_loss: 0.1222  loss_cls: 0.01682  loss_box_reg: 0.03133  loss_mask: 0.07263  loss_rpn_cls: 0.0003928  loss_rpn_loc: 0.003605     lr: 0.00025  max_mem: 1924M
# [07/24 11:25:53 d2.utils.events]:  eta: 0:44:40  iter: 2979  total_loss: 0.1169  loss_cls: 0.0184  loss_box_reg: 0.0256  loss_mask: 0.07018  loss_rpn_cls: 0.0003841  loss_rpn_loc: 0.002885     lr: 0.00025  max_mem: 1924M
# [07/24 11:26:00 d2.utils.events]:  eta: 0:43:31  iter: 2999  total_loss: 0.09927  loss_cls: 0.01344  loss_box_reg: 0.02112  loss_mask: 0.06825  loss_rpn_cls: 0.0001197  loss_rpn_loc: 0.002779     lr: 0.00025  max_mem: 1924M
# [07/24 11:26:08 d2.utils.events]:  eta: 0:45:12  iter: 3019  total_loss: 0.1901  loss_cls: 0.02724  loss_box_reg: 0.05027  loss_mask: 0.09683  loss_rpn_cls: 0.0002964  loss_rpn_loc: 0.004644     lr: 0.00025  max_mem: 1924M
# [07/24 11:26:16 d2.utils.events]:  eta: 0:45:05  iter: 3039  total_loss: 0.1263  loss_cls: 0.01989  loss_box_reg: 0.03843  loss_mask: 0.07458  loss_rpn_cls: 9.289e-05  loss_rpn_loc: 0.003103     lr: 0.00025  max_mem: 1924M
# [07/24 11:26:24 d2.utils.events]:  eta: 0:45:50  iter: 3059  total_loss: 0.1508  loss_cls: 0.02198  loss_box_reg: 0.04641  loss_mask: 0.08232  loss_rpn_cls: 0.0001689  loss_rpn_loc: 0.003551     lr: 0.00025  max_mem: 1924M
# [07/24 11:26:31 d2.utils.events]:  eta: 0:44:15  iter: 3079  total_loss: 0.1061  loss_cls: 0.01607  loss_box_reg: 0.02482  loss_mask: 0.06602  loss_rpn_cls: 0.0001271  loss_rpn_loc: 0.00191     lr: 0.00025  max_mem: 1924M
# Loss has not improved for 100 iterations
# [07/24 11:26:39 d2.utils.events]:  eta: 0:42:46  iter: 3099  total_loss: 0.1376  loss_cls: 0.01603  loss_box_reg: 0.02615  loss_mask: 0.08238  loss_rpn_cls: 0.0002661  loss_rpn_loc: 0.002389     lr: 0.00025  max_mem: 2002M
# [07/24 11:26:47 d2.utils.events]:  eta: 0:46:32  iter: 3119  total_loss: 0.1513  loss_cls: 0.01651  loss_box_reg: 0.03328  loss_mask: 0.0941  loss_rpn_cls: 5.892e-05  loss_rpn_loc: 0.002338     lr: 0.00025  max_mem: 2002M
# [07/24 11:26:55 d2.utils.events]:  eta: 0:43:43  iter: 3139  total_loss: 0.1474  loss_cls: 0.01889  loss_box_reg: 0.03584  loss_mask: 0.07574  loss_rpn_cls: 0.0008801  loss_rpn_loc: 0.003298     lr: 0.00025  max_mem: 2002M
# [07/24 11:27:02 d2.utils.events]:  eta: 0:43:52  iter: 3159  total_loss: 0.1158  loss_cls: 0.01629  loss_box_reg: 0.0238  loss_mask: 0.07667  loss_rpn_cls: 5.641e-05  loss_rpn_loc: 0.00246     lr: 0.00025  max_mem: 2002M
# [07/24 11:27:10 d2.utils.events]:  eta: 0:42:00  iter: 3179  total_loss: 0.1391  loss_cls: 0.02169  loss_box_reg: 0.03458  loss_mask: 0.08038  loss_rpn_cls: 0.0002619  loss_rpn_loc: 0.002807     lr: 0.00025  max_mem: 2002M
# Loss has not improved for 200 iterations
# [07/24 11:27:17 d2.utils.events]:  eta: 0:42:41  iter: 3199  total_loss: 0.108  loss_cls: 0.01991  loss_box_reg: 0.02562  loss_mask: 0.0636  loss_rpn_cls: 0.0001396  loss_rpn_loc: 0.002718     lr: 0.00025  max_mem: 2002M
# [07/24 11:27:25 d2.utils.events]:  eta: 0:43:34  iter: 3219  total_loss: 0.1413  loss_cls: 0.01665  loss_box_reg: 0.03298  loss_mask: 0.08504  loss_rpn_cls: 0.0001372  loss_rpn_loc: 0.003517     lr: 0.00025  max_mem: 2002M
# [07/24 11:27:32 d2.utils.events]:  eta: 0:41:52  iter: 3239  total_loss: 0.1058  loss_cls: 0.01615  loss_box_reg: 0.02365  loss_mask: 0.07096  loss_rpn_cls: 0.0001178  loss_rpn_loc: 0.002464     lr: 0.00025  max_mem: 2002M
# [07/24 11:27:40 d2.utils.events]:  eta: 0:41:42  iter: 3259  total_loss: 0.1212  loss_cls: 0.01722  loss_box_reg: 0.03302  loss_mask: 0.07787  loss_rpn_cls: 0.0001135  loss_rpn_loc: 0.003188     lr: 0.00025  max_mem: 2002M
# [07/24 11:27:48 d2.utils.events]:  eta: 0:43:23  iter: 3279  total_loss: 0.1096  loss_cls: 0.01804  loss_box_reg: 0.02507  loss_mask: 0.06382  loss_rpn_cls: 4.18e-05  loss_rpn_loc: 0.00236     lr: 0.00025  max_mem: 2002M
# Loss has not improved for 300 iterations
# [07/24 11:27:55 d2.utils.events]:  eta: 0:42:11  iter: 3299  total_loss: 0.1301  loss_cls: 0.0172  loss_box_reg: 0.02565  loss_mask: 0.07413  loss_rpn_cls: 0.0001666  loss_rpn_loc: 0.002194     lr: 0.00025  max_mem: 2002M
# [07/24 11:28:03 d2.utils.events]:  eta: 0:43:07  iter: 3319  total_loss: 0.1072  loss_cls: 0.01579  loss_box_reg: 0.02988  loss_mask: 0.0644  loss_rpn_cls: 4.797e-05  loss_rpn_loc: 0.002634     lr: 0.00025  max_mem: 2002M
# [07/24 11:28:11 d2.utils.events]:  eta: 0:42:25  iter: 3339  total_loss: 0.1121  loss_cls: 0.01614  loss_box_reg: 0.02758  loss_mask: 0.06329  loss_rpn_cls: 6.231e-05  loss_rpn_loc: 0.002323     lr: 0.00025  max_mem: 2002M
# [07/24 11:28:18 d2.utils.events]:  eta: 0:42:27  iter: 3359  total_loss: 0.2046  loss_cls: 0.031  loss_box_reg: 0.05899  loss_mask: 0.107  loss_rpn_cls: 0.0002014  loss_rpn_loc: 0.004689     lr: 0.00025  max_mem: 2002M
# [07/24 11:28:26 d2.utils.events]:  eta: 0:41:59  iter: 3379  total_loss: 0.2231  loss_cls: 0.02203  loss_box_reg: 0.04651  loss_mask: 0.1169  loss_rpn_cls: 0.0005527  loss_rpn_loc: 0.0031     lr: 0.00025  max_mem: 2002M
# Loss has not improved for 400 iterations
# [07/24 11:28:34 d2.utils.events]:  eta: 0:42:31  iter: 3399  total_loss: 0.1238  loss_cls: 0.01856  loss_box_reg: 0.0318  loss_mask: 0.0734  loss_rpn_cls: 7.338e-05  loss_rpn_loc: 0.002831     lr: 0.00025  max_mem: 2002M
# [07/24 11:28:41 d2.utils.events]:  eta: 0:41:42  iter: 3419  total_loss: 0.1365  loss_cls: 0.01955  loss_box_reg: 0.03564  loss_mask: 0.07488  loss_rpn_cls: 0.0002105  loss_rpn_loc: 0.002823     lr: 0.00025  max_mem: 2002M
# [07/24 11:28:49 d2.utils.events]:  eta: 0:41:59  iter: 3439  total_loss: 0.1014  loss_cls: 0.01647  loss_box_reg: 0.02579  loss_mask: 0.06035  loss_rpn_cls: 0.0001101  loss_rpn_loc: 0.003325     lr: 0.00025  max_mem: 2002M
# [07/24 11:28:57 d2.utils.events]:  eta: 0:41:35  iter: 3459  total_loss: 0.09976  loss_cls: 0.01452  loss_box_reg: 0.02255  loss_mask: 0.06096  loss_rpn_cls: 8.303e-05  loss_rpn_loc: 0.002262     lr: 0.00025  max_mem: 2002M
# [07/24 11:29:04 d2.utils.events]:  eta: 0:39:10  iter: 3479  total_loss: 0.1446  loss_cls: 0.01807  loss_box_reg: 0.03703  loss_mask: 0.07985  loss_rpn_cls: 0.0001789  loss_rpn_loc: 0.004033     lr: 0.00025  max_mem: 2002M
# Loss has not improved for 500 iterations
# EARLY STOPPING
# WARNING [07/24 11:29:09 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [07/24 11:29:09 d2.data.datasets.coco]: Loaded 12 images in COCO format from ./BENCHmark-1/test/_annotations.coco.json
# [07/24 11:29:09 d2.data.build]: Distribution of instances among all 2 categories:
# |  category  | #instances   |  category  | #instances   |
# |:----------:|:-------------|:----------:|:-------------|
# |  benches   | 0            |  benches   | 20           |
# |            |              |            |              |
# |   total    | 20           |            |              |
# [07/24 11:29:09 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [07/24 11:29:09 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [07/24 11:29:09 d2.data.common]: Serializing 12 elements to byte tensors and concatenating them all ...
# [07/24 11:29:09 d2.data.common]: Serialized dataset takes 0.01 MiB
# [07/24 11:29:09 d2.evaluation.evaluator]: Start inference on 12 batches
# [07/24 11:29:11 d2.evaluation.evaluator]: Inference done 11/12. Dataloading: 0.0012 s/iter. Inference: 0.0829 s/iter. Eval: 0.0031 s/iter. Total: 0.0872 s/iter. ETA=0:00:00
# [07/24 11:29:11 d2.evaluation.evaluator]: Total inference time: 0:00:00.648881 (0.092697 s / iter per device, on 1 devices)
# [07/24 11:29:11 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:00 (0.082666 s / iter per device, on 1 devices)
# [07/24 11:29:11 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [07/24 11:29:11 d2.evaluation.coco_evaluation]: Saving results to ./output/inference/asl_poly_test/coco_instances_results.json
# [07/24 11:29:11 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# [07/24 11:29:11 d2.evaluation.fast_eval_api]: Evaluate annotation type *bbox*
# [07/24 11:29:11 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.00 seconds.
# [07/24 11:29:11 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [07/24 11:29:11 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.01 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.595
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.763
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.656
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.297
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.900
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.751
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.460
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.635
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.635
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.314
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.900
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.800
# [07/24 11:29:11 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl   |
# |:------:|:------:|:------:|:------:|:------:|:------:|
# | 59.539 | 76.348 | 65.613 | 29.736 | 90.000 | 75.094 |
# [07/24 11:29:11 d2.evaluation.coco_evaluation]: Per-category bbox AP:
# | category   | AP   | category   | AP     |
# |:-----------|:-----|:-----------|:-------|
# | benches    | nan  | benches    | 59.539 |
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# [07/24 11:29:11 d2.evaluation.fast_eval_api]: Evaluate annotation type *segm*
# [07/24 11:29:11 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.01 seconds.
# [07/24 11:29:11 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [07/24 11:29:11 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.01 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.525
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.754
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.520
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.181
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.800
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.700
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.430
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.560
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.560
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.229
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.800
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.733
# [07/24 11:29:11 d2.evaluation.coco_evaluation]: Evaluation results for segm:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl   |
# |:------:|:------:|:------:|:------:|:------:|:------:|
# | 52.505 | 75.353 | 51.951 | 18.076 | 80.000 | 70.002 |
# [07/24 11:29:11 d2.evaluation.coco_evaluation]: Per-category segm AP:
# | category   | AP   | category   | AP     |
# |:-----------|:-----|:-----------|:-------|
# | benches    | nan  | benches    | 52.505 |
# [07/24 11:29:11 detectron2]: Evaluation results for asl_poly_test in csv format:
# [07/24 11:29:11 d2.evaluation.testing]: copypaste: Task: bbox
# [07/24 11:29:11 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [07/24 11:29:11 d2.evaluation.testing]: copypaste: 59.5389,76.3476,65.6128,29.7360,90.0000,75.0938
# [07/24 11:29:11 d2.evaluation.testing]: copypaste: Task: segm
# [07/24 11:29:11 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [07/24 11:29:11 d2.evaluation.testing]: copypaste: 52.5046,75.3534,51.9511,18.0764,80.0000,70.0019
# OrderedDict([('bbox',
#               {'AP': 59.53892448068336,
#                'AP50': 76.34763476347635,
#                'AP75': 65.6127797653715,
#                'APs': 29.73597359735973,
#                'APm': 90.0,
#                'APl': 75.0938236680811,
#                'AP-benches': 59.53892448068336}),
#              ('segm',
#               {'AP': 52.50455717840692,
#                'AP50': 75.35341769471067,
#                'AP75': 51.951077460687245,
#                'APs': 18.076379066478072,
#                'APm': 80.0,
#                'APl': 70.0019040365575,
#                'AP-benches': 52.50455717840692})])

# %% [markdown]
# # Test model and show example output

# %%
cfg.MODEL.WEIGHTS = os.path.join(cfg.OUTPUT_DIR, "model_final.pth")  # path to the model we just trained
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.2   # set a custom testing threshold
predictor = DefaultPredictor(cfg)

dataset_dicts = DatasetCatalog.get("asl_poly_valid")
for d in random.sample(dataset_dicts, 3):
    im = cv2.imread(d["file_name"])
    outputs = predictor(im)
    v = Visualizer(im[:, :, ::-1],
                   scale=0.5,
                   instance_mode=ColorMode.IMAGE_BW
    )
    out = v.draw_instance_predictions(outputs["instances"].to("cpu"))
    im = Image.fromarray(out.get_image()[:, :, ::-1])
    im
# Out:
# [07/24 11:36:30 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from ./output/inference/asl_poly_test/instances_predictions.pth ...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-01d99fe98f1c> in <cell line: 3>()
#       1 cfg.MODEL.WEIGHTS = os.path.join(cfg.OUTPUT_DIR, "inference/asl_poly_test/instances_predictions.pth")  # path to the model we just trained
#       2 cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.2   # set a custom testing threshold
# ----> 3 predictor = DefaultPredictor(cfg)
#       4
#       5 dataset_dicts = DatasetCatalog.get("asl_poly_valid")
#
# /usr/local/lib/python3.10/dist-packages/detectron2/engine/defaults.py in __init__(self, cfg)
#     286
#     287         checkpointer = DetectionCheckpointer(self.model)
# --> 288         checkpointer.load(cfg.MODEL.WEIGHTS)
#     289
#     290         self.aug = T.ResizeShortestEdge(
#
# /usr/local/lib/python3.10/dist-packages/detectron2/checkpoint/detection_checkpoint.py in load(self, path, *args, **kwargs)
#      60             path = parsed_url._replace(query="").geturl()  # remove query from filename
#      61             path = self.path_manager.get_local_path(path)
# ---> 62         ret = super().load(path, *args, **kwargs)
#      63
#      64         if need_sync:
#
# /usr/local/lib/python3.10/dist-packages/fvcore/common/checkpoint.py in load(self, path, checkpointables)
#     154
#     155         checkpoint = self._load_file(path)
# --> 156         incompatible = self._load_model(checkpoint)
#     157         if (
#     158             incompatible is not None
#
# /usr/local/lib/python3.10/dist-packages/detectron2/checkpoint/detection_checkpoint.py in _load_model(self, checkpoint)
#     124             )
#     125         # for non-caffe2 models, use standard ways to load it
# --> 126         incompatible = super()._load_model(checkpoint)
#     127
#     128         model_buffers = dict(self.model.named_buffers(recurse=False))
#
# /usr/local/lib/python3.10/dist-packages/fvcore/common/checkpoint.py in _load_model(self, checkpoint)
#     271         """
#     272         checkpoint_state_dict = checkpoint.pop("model")
# --> 273         self._convert_ndarray_to_tensor(checkpoint_state_dict)
#     274
#     275         # if the state_dict comes from a model that was wrapped in a
#
# /usr/local/lib/python3.10/dist-packages/fvcore/common/checkpoint.py in _convert_ndarray_to_tensor(self, state_dict)
#     364         # (as returned by Pytorch's state_dict()). We should preserve these
#     365         # properties.
# --> 366         for k in list(state_dict.keys()):
#     367             v = state_dict[k]
#     368             if not isinstance(v, np.ndarray) and not isinstance(v, torch.Tensor):
#
# AttributeError: 'list' object has no attribute 'keys'

# %%
im
# Out:
# <PIL.Image.Image image mode=RGB size=208x208 at 0x7F8EF05C2210>

# %% [markdown]
# # Download trained model for future inference

# %%
from google.colab import files
files.download(os.path.join(cfg.OUTPUT_DIR, "model_final.pth"))
